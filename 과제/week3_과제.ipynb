# %% [markdown]
# <a href="https://colab.research.google.com/github/kimsuckhyun/Computer_Vision_Seminar/blob/main/%EA%B3%BC%EC%A0%9C/week3_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/CV_seminar_project/ # 현재 경로를 앞으로 진행할 프로젝트 디렉토리로 이동한다.
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CV_seminar_project/ # 현재 경로를 앞으로 진행할 프로젝트 디렉토리로 이동한다.'
# /content

# %%
import os
import glob
import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import random
# %matplotlib inline

# %%
def read_img(file_path):
    img_arr=cv2.imread(file_path)
    return cv2.cvtColor(img_arr,cv2.COLOR_BGR2RGB)

path='/content/drive/MyDrive/CV_seminar_project/train'
dolphin = glob.glob(path+'/dolphin/*')
shark = glob.glob(path+'/shark/*')
whale = glob.glob(path+'/whale/*')

img_arrs=[]
img_num=range(0,200)

for i in random.sample(img_num,3):
    img_arrs.append(read_img(dolphin[i]))
    img_arrs.append(read_img(shark[i]))
    img_arrs.append(read_img(whale[i]))

rows=3
columns=3

fig,axes=plt.subplots(nrows=rows,ncols=columns,figsize=(columns*3,rows*3))

for num in range(1,rows*columns+1):
    
    fig.add_subplot(rows,columns,num)
    idx=num-1
    
    plt.imshow(img_arrs[idx],aspect='auto')
    plt.xlabel(f'{img_arrs[idx].shape}',fontsize=12)
    
fig.tight_layout()

cols=['dolphin','shark','whale']

for folder_idx,ax in enumerate(axes[0]):
    ax.set_title(cols[folder_idx])

for idx,ax in enumerate(axes.flat):
    ax.set_xticks([])
    ax.set_yticks([])

# %%
# 처음이미지

img_arr=cv2.imread(dolphin[113])
first_img_arr=cv2.cvtColor(img_arr,cv2.COLOR_BGR2RGB)
print(first_img_arr.shape) # (259,194,3)이다
# a=plt.imshow(first_img_arr,aspect='auto') (이미지 출력)

# 바뀐이미지

chage_img_arr=first_img_arr.transpose(2,0,1) # 다시 이미지로 표현하기 위해선 transpose(1,2,0)을 해준다. 
print(chage_img_arr.shape)

index1=int(chage_img_arr.shape[1]/20)
column1=int(chage_img_arr.shape[2]/10)
column1_left,column1_right=column1,chage_img_arr.shape[2]-column1 
color_list=[[0,0,0],[255,0,0],[0,255,0],[0,0,255],[255,255,255]] 

for i,j,color in zip(range(index1*2,chage_img_arr.shape[1],index1*4),range(index1*3,chage_img_arr.shape[1],index1*4),color_list):        
    chage_img_arr[0,i:j,column1_left:column1_right]=color[0]
    chage_img_arr[1,i:j,column1_left:column1_right]=color[1]
    chage_img_arr[2,i:j,column1_left:column1_right]=color[2]

chage_img_arr=chage_img_arr.transpose(1,2,0)
a=plt.imshow(chage_img_arr,aspect='auto')
# Out:
# (206, 245, 3)
# (3, 206, 245)

# %%
chage_img_arr=first_img_arr.transpose(2,0,1)
chage_img_arr
# Out:
# array([[[  1,   1,   1, ...,   3,   2,   2],
#         [  1,   1,   1, ...,   3,   2,   2],
#         [  1,   1,   1, ...,   3,   2,   2],
#         ...,
#         [  0,   0,   0, ...,   2,   1,   1],
#         [  0,   0,   0, ...,   1,   1,   0],
#         [  0,   0,   0, ...,   1,   0,   0]],
#
#        [[119, 119, 119, ...,  90,  89,  89],
#         [119, 119, 119, ...,  90,  89,  89],
#         [119, 119, 119, ...,  90,  89,  89],
#         ...,
#         [ 66,  66,  66, ...,  48,  47,  47],
#         [ 66,  66,  66, ...,  47,  47,  46],
#         [ 66,  66,  66, ...,  47,  46,  46]],
#
#        [[155, 155, 155, ..., 120, 119, 119],
#         [155, 155, 155, ..., 120, 119, 119],
#         [155, 155, 155, ..., 120, 119, 119],
#         ...,
#         [ 92,  92,  92, ...,  71,  70,  70],
#         [ 92,  92,  92, ...,  70,  70,  69],
#         [ 92,  92,  92, ...,  70,  69,  69]]], dtype=uint8)

# %%
img_arr[0,10:20,10:30]=0
img_arr[1,10:20,10:30]=0
img_arr[2,10:20,10:30]=0
